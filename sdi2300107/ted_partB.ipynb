# %%
# Setup: install packages and import everything used in the notebook.
# %pip install ipykernel pandas numpy scipy scikit-learn matplotlib seaborn wordcloud gensim vaderSentiment nltk

# Core data handling
import re
import pandas as pd
import numpy as np
from scipy import stats   # used for the Welch t-test on sentiment

# IO and NLP
import tarfile      # read the lyrics tar.gz directly
import gensim       # for Word2Vec
import nltk         # for the english stopword list
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Download the english stopwords once
nltk.download('stopwords', quiet=True)
from nltk.corpus import stopwords
STOP_WORDS = set(stopwords.words('english'))

# Machine learning tools
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler   # scale features before PCA
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Reproducibility
np.random.seed(42)
# Out:
# Requirement already satisfied: ipykernel in ./.venv312/lib/python3.13/site-packages (7.2.0)
# Requirement already satisfied: pandas in ./.venv312/lib/python3.13/site-packages (3.0.2)
# Requirement already satisfied: numpy in ./.venv312/lib/python3.13/site-packages (2.4.4)
# Requirement already satisfied: scipy in ./.venv312/lib/python3.13/site-packages (1.17.1)
# Requirement already satisfied: scikit-learn in ./.venv312/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: matplotlib in ./.venv312/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: seaborn in ./.venv312/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: wordcloud in ./.venv312/lib/python3.13/site-packages (1.9.6)
# Requirement already satisfied: gensim in ./.venv312/lib/python3.13/site-packages (4.4.0)
# Requirement already satisfied: vaderSentiment in ./.venv312/lib/python3.13/site-packages (3.3.2)
# Requirement already satisfied: nltk in ./.venv312/lib/python3.13/site-packages (3.9.4)
# Requirement already satisfied: comm>=0.1.1 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (9.12.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (26.1)
# Requirement already satisfied: psutil>=5.7 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv312/lib/python3.13/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv312/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.3.0 in ./.venv312/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./.venv312/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv312/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv312/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv312/lib/python3.13/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv312/lib/python3.13/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in ./.venv312/lib/python3.13/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv312/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: smart_open>=1.8.1 in ./.venv312/lib/python3.13/site-packages (from gensim) (7.6.0)
# Requirement already satisfied: requests in ./.venv312/lib/python3.13/site-packages (from vaderSentiment) (2.33.1)
# Requirement already satisfied: click in ./.venv312/lib/python3.13/site-packages (from nltk) (8.3.3)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv312/lib/python3.13/site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in ./.venv312/lib/python3.13/site-packages (from nltk) (4.67.3)
# Requirement already satisfied: decorator>=5.1.0 in ./.venv312/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv312/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in ./.venv312/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.6 in ./.venv312/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv312/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in ./.venv312/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv312/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv312/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv312/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv312/lib/python3.13/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.9.6)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv312/lib/python3.13/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv312/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: wrapt in ./.venv312/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv312/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv312/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv312/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv312/lib/python3.13/site-packages (from requests->vaderSentiment) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv312/lib/python3.13/site-packages (from requests->vaderSentiment) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv312/lib/python3.13/site-packages (from requests->vaderSentiment) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv312/lib/python3.13/site-packages (from requests->vaderSentiment) (2026.4.22)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Εξόρυξη Γνώσης από Μουσικά Δεδομένα (Audio & Lyrics)
#
# **Ομάδα:**
# * Παναγιώτης Μακαρόνας (AM: sdi2300107)
# * Αχιλλέας Νιανιακούδης-Κοέν (AM: sdi2300138)

# %% [markdown]
# ## 1. Συλλογή Δεδομένων (Data collection)
# Σε αυτό το κελί φορτώνονται τα δεδομένα, εφαρμόζεται το φιλτράρισμα στα Top-5 Genres και πραγματοποιείται το intersection των αρχείων.

# %%
# File paths
genres_path = "data/id_genres.csv"
info_path = "data/id_information.csv"
mfcc_path = "data/id_mfcc_stats.tsv.bz2"
tags_path = "data/id_tags.csv"
lyrics_archive = "data/processed_lyrics.tar.gz"

# Small TSV files (despite the .csv extension they are tab-separated)
df_genres = pd.read_csv(genres_path, sep='\t')
df_info = pd.read_csv(info_path, sep='\t')
df_tags = pd.read_csv(tags_path, sep='\t')

# Read the large MFCC file in 2000-row chunks to keep memory low
mfcc_chunks = []
for chunk in pd.read_csv(mfcc_path, sep='\t', compression='bz2', chunksize=2000):
    mfcc_chunks.append(chunk)
df_mfcc = pd.concat(mfcc_chunks, ignore_index=True)

# Make sure the song id column is named 'id' so merges are unambiguous
mfcc_id_col = df_mfcc.columns[0]
if mfcc_id_col != 'id':
    df_mfcc = df_mfcc.rename(columns={mfcc_id_col: 'id'})

# Drop a possible 'genre' column inside MFCC to avoid merge collisions
if 'genre' in df_mfcc.columns:
    df_mfcc = df_mfcc.drop(columns=['genre'])

# Each row has comma-separated genres; explode to one (song, genre) pair per row
df_genres['genre'] = df_genres['genres'].str.split(',')
df_genres = df_genres.explode('genre')
df_genres['genre'] = df_genres['genre'].str.strip()

# Keep only the Top-5 most frequent genres
top5 = df_genres['genre'].value_counts().head(5).index.tolist()
df_genres = df_genres[df_genres['genre'].isin(top5)]
print(f"Top-5 genres: {top5}")

# One genre per song (first match)
df_genres = df_genres.drop_duplicates(subset='id', keep='first')

# Explicit (id -> genre) dict so we can re-attach the label after any merge
genre_map = dict(zip(df_genres['id'].astype(str), df_genres['genre']))

# Intersection: only keep songs present in genres AND mfcc AND lyrics
genre_ids = set(df_genres['id'].astype(str))
mfcc_ids = set(df_mfcc['id'].astype(str))
common_ids = genre_ids & mfcc_ids

# Stream the lyrics tar.gz, extracting only files for songs we actually need
lyrics_dict = {}
with tarfile.open(lyrics_archive, 'r:gz') as tar:
    for member in tar:
        if not member.isfile():
            continue
        song_id = member.name.split('/')[-1].replace('.txt', '')
        if song_id in common_ids:
            f = tar.extractfile(member)
            if f:
                lyrics_dict[song_id] = f.read().decode('utf-8', errors='ignore')

df_lyrics = pd.DataFrame(list(lyrics_dict.items()), columns=['id', 'lyrics'])
final_ids = common_ids & set(df_lyrics['id'])

# Build df from a known-good base (lyrics) and attach genre via the map
df = df_lyrics[df_lyrics['id'].isin(final_ids)].copy()
df['id'] = df['id'].astype(str)
df['genre'] = df['id'].map(genre_map)

# Merge MFCC features. suffixes=('', '_mfcc') protects our existing columns
df_mfcc['id'] = df_mfcc['id'].astype(str)
df = df.merge(df_mfcc, on='id', how='left', suffixes=('', '_mfcc'))

# Re-assert genre after the merge (defensive against any version-specific quirks)
df['genre'] = df['id'].map(genre_map)

assert 'genre' in df.columns
assert df['genre'].isna().sum() == 0

# Balanced sampling: up to 2000 songs per genre
SAMPLE_PER_GENRE = 2000
df_sampled = []
for g in df['genre'].unique():
    genre_df = df[df['genre'] == g]
    sampled = genre_df.sample(min(len(genre_df), SAMPLE_PER_GENRE), random_state=42)
    df_sampled.append(sampled)
df = pd.concat(df_sampled, ignore_index=True)

# De-fragment after all the column work to silence pandas PerformanceWarning
df = df.copy()

print(f"\nFinal dataset: {len(df)} songs across {df['genre'].nunique()} genres")
print(df['genre'].value_counts())
print(df[['id', 'genre', 'lyrics']].head())
# Out:
# Top-5 genres: ['rock', 'pop', 'electronic', 'alternative rock', 'indie rock']
#
# Final dataset: 10000 songs across 5 genres
# genre
# rock                2000
# alternative rock    2000
# pop                 2000
# indie rock          2000
# electronic          2000
# Name: count, dtype: int64
#                  id genre                                             lyrics
# 0  uORMwZEydnnPWCf3  rock  move talk time think worri everyth fine fine g...
# 1  tF4fFZp2rIPnr2T7  rock  larri call load smoke want lose coupl day prob...
# 2  yKqVJ4TBJzPDJABc  rock  light green green dark green brown everi life ...
# 3  NwbcLd9ls0zUSu8E  rock  east mode everybodi strike pose everybodi tax ...
# 4  zGdLJNjLygap1tYJ  rock  say exist help say exist protect know stop kno...

# %% [markdown]
# ## 2. Εξαγωγή Χαρακτηριστικών & Embeddings (Feature Extraction)
# Εδώ δημιουργούνται οι διανυσματικές αναπαραστάσεις για το κείμενο (Word2Vec, με average-pooling των word vectors ανά τραγούδι) και για τον ήχο (StandardScaler + PCA στα MFCCs ώστε όλα τα features να έχουν την ίδια κλίμακα πριν την μείωση διαστάσεων).

# %%
# Text embeddings: Word2Vec with average-pooling per song
from gensim.models import Word2Vec

# Simple regex tokenizer (lowercase, alphanumeric + apostrophe).
# Better than .split() because it strips punctuation cleanly.
_TOKEN_RE = re.compile(r"[a-z0-9']+")
def tokenize(text):
    return _TOKEN_RE.findall(text.lower())

tokenized = df['lyrics'].apply(tokenize).tolist()

# 128-dim vectors, window of 5, drop words seen only once. workers=1 + seed
# makes training reproducible (small enough corpus for that to be fine).
w2v_model = Word2Vec(sentences=tokenized, vector_size=128,
                     window=5, min_count=2, workers=1, seed=42, epochs=10)
print(f"Word2Vec vocabulary size: {len(w2v_model.wv)}")

def song_text_embedding(words, model):
    # Average all known word vectors. Empty / all-OOV songs become zero vectors.
    vecs = [model.wv[w] for w in words if w in model.wv]
    return np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size)

text_embeddings = np.vstack(
    [song_text_embedding(tok, w2v_model) for tok in tokenized]
)
print(f"Text embeddings shape: {text_embeddings.shape}")

# Audio embeddings: StandardScaler + PCA on the MFCC stats.
# Everything that is not a bookkeeping/text column is an MFCC feature.
mfcc_cols = [c for c in df.columns if c not in ['id', 'genre', 'lyrics', 'genres']]
mfcc_matrix = df[mfcc_cols].values.astype(np.float32)

# A few MFCC stats can be NaN/Inf for very short tracks. Replace with 0.
mfcc_matrix = np.nan_to_num(mfcc_matrix, nan=0.0, posinf=0.0, neginf=0.0)

# Standardize before PCA so no single feature dominates the variance.
scaler = StandardScaler()
mfcc_scaled = scaler.fit_transform(mfcc_matrix)

# Keep enough PCA components to explain 95% of variance.
pca = PCA(n_components=0.95, random_state=42)
audio_embeddings = pca.fit_transform(mfcc_scaled)
print(f"Audio PCA: {mfcc_matrix.shape[1]} dims -> {audio_embeddings.shape[1]} dims "
      f"({pca.n_components_} components, 95% variance)")

# Attach both embeddings to df in one shot to avoid fragmentation.
df = pd.concat([
    df,
    pd.DataFrame({'text_emb': list(text_embeddings),
                  'audio_emb': list(audio_embeddings)}, index=df.index),
], axis=1).copy()
print("Embeddings stored in DataFrame")
# Out:
# Word2Vec vocabulary size: 12413
# Text embeddings shape: (10000, 128)
# Audio PCA: 104 dims -> 79 dims (79 components, 95% variance)
# Embeddings stored in DataFrame

# %% [markdown]
# ## 3. Οπτικοποίηση και Ανάλυση (Exploratory Data Analysis - EDA)
# Ανάλυση των tags, word clouds, 2D projections (PCA/t-SNE) και Cosine Similarity.

# %%
# Attach the user tags to each song (left-join keeps every song)
df_tags['id'] = df_tags['id'].astype(str).str.strip()
df_with_tags = df.merge(df_tags, on='id', how='left')

# 3a. Word clouds for the two most-different genres.
# We pick the pair automatically using Jaccard distance on each genre's
# top-30 tags (lower Jaccard = more different).
genre_top_tag_sets = {}
for g in df['genre'].unique():
    g_tag_strings = df_with_tags[df_with_tags['genre'] == g]['tags'].dropna().astype(str)
    g_tags_flat = g_tag_strings.str.split(',').explode().str.strip()
    genre_top_tag_sets[g] = set(g_tags_flat.value_counts().head(30).index)

print("Tag-set Jaccard similarity between Top-5 genres (lower = more different):")
genre_list = sorted(genre_top_tag_sets)
best_pair, best_dist = None, -1.0
for i in range(len(genre_list)):
    for j in range(i + 1, len(genre_list)):
        a, b = genre_top_tag_sets[genre_list[i]], genre_top_tag_sets[genre_list[j]]
        jacc = len(a & b) / len(a | b) if (a | b) else 0.0
        dist = 1.0 - jacc
        print(f"  {genre_list[i]:14s} vs {genre_list[j]:14s}  Jaccard={jacc:.3f}  Distance={dist:.3f}")
        if dist > best_dist:
            best_dist, best_pair = dist, (genre_list[i], genre_list[j])

genre_a, genre_b = best_pair
print(f"\nMost different pair: '{genre_a}' vs '{genre_b}' (distance={best_dist:.3f})")

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
for ax, genre in zip(axes, [genre_a, genre_b]):
    # Concatenate all tag strings for this genre; WordCloud counts internally
    genre_tags = df_with_tags[df_with_tags['genre'] == genre]['tags'].dropna()
    all_tags_text = ' '.join(genre_tags.astype(str))
    wc = WordCloud(width=800, height=400, background_color='white',
                   colormap='viridis', max_words=100).generate(all_tags_text)
    ax.imshow(wc, interpolation='bilinear')
    ax.set_title(f"Word Cloud — {genre}", fontsize=14, fontweight='bold')
    ax.axis('off')

plt.suptitle(f"Tag Word Clouds: {genre_a} vs {genre_b} (auto-picked)",
             fontsize=15, fontweight='bold')
plt.tight_layout()
plt.show()

# 3b. Top-10 tags across the whole dataset (required by the assignment)
all_tags = df_with_tags['tags'].dropna().astype(str)
tag_series = all_tags.str.split(',').explode().str.strip()
tag_counts = tag_series.value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=tag_counts.values, y=tag_counts.index, hue=tag_counts.index,
            palette='viridis', legend=False)
plt.xlabel("Frequency", fontsize=12)
plt.ylabel("Tag", fontsize=12)
plt.title("Top 10 Most Frequent Tags Across All Songs", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# Top-10 tags per genre (extra)
fig, axes = plt.subplots(1, 5, figsize=(28, 6), sharey=False)
for ax, genre in zip(axes, sorted(df['genre'].unique())):
    genre_tags = df_with_tags[df_with_tags['genre'] == genre]['tags'].dropna().astype(str)
    tags_flat = genre_tags.str.split(',').explode().str.strip()
    top10 = tags_flat.value_counts().head(10)
    sns.barplot(x=top10.values, y=top10.index, hue=top10.index,
                palette='viridis', legend=False, ax=ax)
    ax.set_title(genre, fontsize=12, fontweight='bold')
    ax.set_xlabel("Frequency")
    ax.set_ylabel("")

plt.suptitle("Top 10 Tags per Genre (extra)", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# 3c. How many genres each song has, in the raw (unfiltered) data
df_genres_raw = pd.read_csv("data/id_genres.csv", sep='\t')
genres_per_song = df_genres_raw['genres'].str.split(',').apply(len)

plt.figure(figsize=(8, 5))
genres_per_song.value_counts().sort_index().plot(kind='bar', color='steelblue', edgecolor='black')
plt.xlabel("Πλήθος Genres ανά Τραγούδι", fontsize=12)
plt.ylabel("Πλήθος Τραγουδιών", fontsize=12)
plt.title("Κατανομή Ειδών ανά Τραγούδι (πριν το filtering)", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print(f"Μέσος αριθμός genres/τραγούδι: {genres_per_song.mean():.2f}")
print(f"Max genres σε ένα τραγούδι: {genres_per_song.max()}")

# 3c-bis. Top-N most popular genres in the raw data (reverse view)
TOP_N = 10
genre_freq_raw = (df_genres_raw['genres']
                  .str.split(',').explode().str.strip()
                  .value_counts().head(TOP_N))

plt.figure(figsize=(11, 5))
sns.barplot(x=genre_freq_raw.values, y=genre_freq_raw.index,
            hue=genre_freq_raw.index, palette='magma', legend=False)
plt.xlabel("Πλήθος Τραγουδιών", fontsize=12)
plt.ylabel("Genre", fontsize=12)
plt.title(f"Top-{TOP_N} Genres στο πλήρες dataset (πριν το filtering)",
          fontsize=14, fontweight='bold')
for i, v in enumerate(genre_freq_raw.values):
    plt.text(v, i, f" {v}", va='center', fontweight='bold')
plt.tight_layout()
plt.show()

# 3d. Songs per Top-5 genre after the balanced sampling
genre_counts = df['genre'].value_counts()

plt.figure(figsize=(10, 5))
sns.barplot(x=genre_counts.index, y=genre_counts.values, hue=genre_counts.index,
            palette='Set2', legend=False)
plt.xlabel("Genre", fontsize=12)
plt.ylabel("Πλήθος Τραγουδιών", fontsize=12)
plt.title("Κατανομή Τραγουδιών ανά Top-5 Genre (μετά το sampling)", fontsize=14, fontweight='bold')
for i, v in enumerate(genre_counts.values):
    plt.text(i, v + 20, str(v), ha='center', fontweight='bold')
plt.tight_layout()
plt.show()

# 3e. Lyrics length stats. Build all derived columns at once with concat
# so pandas does not warn about a fragmented frame.
_lyrics_stats = pd.DataFrame({
    'word_count': df['lyrics'].apply(lambda x: len(x.split())),
    'char_count': df['lyrics'].apply(len),
    'meaningful_words': df['lyrics'].apply(
        lambda x: len([w for w in x.lower().split() if w not in STOP_WORDS])
    ),
}, index=df.index)
df = pd.concat([df, _lyrics_stats], axis=1).copy()

fig, axes = plt.subplots(1, 3, figsize=(20, 5))
axes[0].hist(df['word_count'], bins=50, color='steelblue', edgecolor='black', alpha=0.7)
axes[0].set_title("Κατανομή Πλήθους Λέξεων", fontsize=13, fontweight='bold')
axes[0].set_xlabel("Πλήθος Λέξεων")
axes[0].set_ylabel("Τραγούδια")

axes[1].hist(df['char_count'], bins=50, color='coral', edgecolor='black', alpha=0.7)
axes[1].set_title("Κατανομή Πλήθους Χαρακτήρων", fontsize=13, fontweight='bold')
axes[1].set_xlabel("Πλήθος Χαρακτήρων")
axes[1].set_ylabel("Τραγούδια")

axes[2].hist(df['meaningful_words'], bins=50, color='mediumseagreen', edgecolor='black', alpha=0.7)
axes[2].set_title("Κατανομή Meaningful Λέξεων (χωρίς stopwords)", fontsize=13, fontweight='bold')
axes[2].set_xlabel("Πλήθος Meaningful Λέξεων")
axes[2].set_ylabel("Τραγούδια")

plt.suptitle("Στατιστικά Μήκους Στίχων", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

print(f"Μέση λέξεις/τραγούδι: {df['word_count'].mean():.0f}, "
      f"Μέσοι χαρακτήρες: {df['char_count'].mean():.0f}, "
      f"Μέσες meaningful λέξεις: {df['meaningful_words'].mean():.0f}")

# 3f. Sentiment with VADER. Compute on a side Series and concat to avoid fragmentation.
analyzer = SentimentIntensityAnalyzer()
_sentiment = df['lyrics'].apply(lambda x: analyzer.polarity_scores(x)['compound']).rename('sentiment')
df = pd.concat([df, _sentiment], axis=1).copy()

plt.figure(figsize=(10, 6))
sns.boxplot(x='genre', y='sentiment', data=df, hue='genre', palette='Set2', legend=False)
plt.xlabel("Genre", fontsize=12)
plt.ylabel("VADER Compound Score", fontsize=12)
plt.title("Ανάλυση Συναισθήματος Στίχων ανά Genre (VADER)", fontsize=14, fontweight='bold')
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

print("Μέσο Sentiment (compound) ανά genre:")
print(df.groupby('genre')['sentiment'].agg(['mean', 'median', 'std']).round(3))

# Welch t-test for the assignment hypothesis: "is pop happier than rock?"
present_genres = set(df['genre'].unique())
if {'pop', 'rock'} <= present_genres:
    pop_sent = df.loc[df['genre'] == 'pop', 'sentiment'].dropna()
    rock_sent = df.loc[df['genre'] == 'rock', 'sentiment'].dropna()
    t_stat, p_val = stats.ttest_ind(pop_sent, rock_sent, equal_var=False)
    diff = pop_sent.mean() - rock_sent.mean()
    print(f"\nWelch t-test (pop vs rock sentiment):")
    print(f"  t = {t_stat:+.3f},  p-value = {p_val:.4g}")
    print(f"  mean(pop) - mean(rock) = {diff:+.3f}")
    if p_val < 0.05:
        if diff > 0:
            print("  ΥΠΟΘΕΣΗ ΕΠΙΒΕΒΑΙΩΝΕΤΑΙ: το pop είναι σημαντικά πιο θετικό (α=0.05).")
        else:
            print("  ΥΠΟΘΕΣΗ ΑΠΟΡΡΙΠΤΕΤΑΙ: η διαφορά είναι σημαντική αλλά αντίθετη.")
    else:
        print("  ΥΠΟΘΕΣΗ ΔΕΝ ΕΠΙΒΕΒΑΙΩΝΕΤΑΙ: η διαφορά δεν είναι στατιστικά σημαντική.")
else:
    print("\n[Sentiment t-test skipped: 'pop' ή 'rock' δεν είναι στα Top-5.]")

# 3g. 2D projections with both t-SNE (non-linear) and PCA (linear)
tsne_text = TSNE(n_components=2, perplexity=30, random_state=42, max_iter=1500)
text_2d = tsne_text.fit_transform(text_embeddings)

tsne_audio = TSNE(n_components=2, perplexity=30, random_state=42, max_iter=1500)
audio_2d = tsne_audio.fit_transform(audio_embeddings)

pca_text_2d = PCA(n_components=2, random_state=42).fit_transform(text_embeddings)
pca_audio_2d = PCA(n_components=2, random_state=42).fit_transform(audio_embeddings)

fig, axes = plt.subplots(2, 2, figsize=(18, 13))
panels = [
    (axes[0, 0], text_2d,       "Text Embeddings (t-SNE)",  "Dim 1", "Dim 2"),
    (axes[0, 1], audio_2d,      "Audio Embeddings (t-SNE)", "Dim 1", "Dim 2"),
    (axes[1, 0], pca_text_2d,   "Text Embeddings (PCA)",    "PC1",   "PC2"),
    (axes[1, 1], pca_audio_2d,  "Audio Embeddings (PCA)",   "PC1",   "PC2"),
]
for ax, data_2d, title, xl, yl in panels:
    for genre in df['genre'].unique():
        mask = df['genre'] == genre
        ax.scatter(data_2d[mask, 0], data_2d[mask, 1], label=genre, alpha=0.5, s=15)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_xlabel(xl); ax.set_ylabel(yl)
    ax.legend(fontsize=9, markerscale=2)

plt.suptitle("2D Projections: t-SNE (top) vs PCA (bottom), colored by Genre",
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# 3h. Cosine similarity. We use 3 query songs (one per genre) so the comparison
# is not anecdotal. Bring artist/title in for readable output.
df_info['id'] = df_info['id'].astype(str).str.strip()
df_named = df.merge(df_info, on='id', how='left')

def _label(row):
    artist = row.get('artist', None)
    title = row.get('song', None)
    if title is None:
        title = row.get('title', None)
    artist = artist if isinstance(artist, str) and artist else "?"
    title = title if isinstance(title, str) and title else "?"
    return f"{artist} — {title}"

# One deterministic query per genre, from the first three genres
rng = np.random.default_rng(42)
query_indices = []
for g in sorted(df['genre'].unique())[:3]:
    cand = np.where(df['genre'].values == g)[0]
    query_indices.append(int(rng.choice(cand)))

for q_idx in query_indices:
    q_song = df_named.iloc[q_idx]
    print("\n" + "=" * 78)
    print(f"QUERY: [{q_song['genre']:12s}] {_label(q_song)}  (id={q_song['id']})")
    print("=" * 78)

    # Text-side neighbors
    text_sim = cosine_similarity([text_embeddings[q_idx]], text_embeddings)[0]
    text_sim[q_idx] = -1   # hide the query itself
    top5_text = np.argsort(text_sim)[-5:][::-1]
    print("\n  Top 5 by TEXT (lyrics) similarity:")
    for r, i in enumerate(top5_text, 1):
        s = df_named.iloc[i]
        print(f"    {r}. [{s['genre']:12s}] {_label(s)[:55]:55s}  sim={text_sim[i]:+.3f}")

    # Audio-side neighbors
    audio_sim = cosine_similarity([audio_embeddings[q_idx]], audio_embeddings)[0]
    audio_sim[q_idx] = -1
    top5_audio = np.argsort(audio_sim)[-5:][::-1]
    print("\n  Top 5 by AUDIO (MFCC) similarity:")
    for r, i in enumerate(top5_audio, 1):
        s = df_named.iloc[i]
        print(f"    {r}. [{s['genre']:12s}] {_label(s)[:55]:55s}  sim={audio_sim[i]:+.3f}")

    text_hits = sum(df.iloc[i]['genre'] == q_song['genre'] for i in top5_text)
    audio_hits = sum(df.iloc[i]['genre'] == q_song['genre'] for i in top5_audio)
    print(f"\n  Same-genre hits  TEXT: {text_hits}/5   AUDIO: {audio_hits}/5")
# Out:
# Tag-set Jaccard similarity between Top-5 genres (lower = more different):
#   alternative rock vs electronic      Jaccard=0.132  Distance=0.868
#   alternative rock vs indie rock      Jaccard=0.277  Distance=0.723
#   alternative rock vs pop             Jaccard=0.200  Distance=0.800
#   alternative rock vs rock            Jaccard=0.463  Distance=0.537
#   electronic     vs indie rock      Jaccard=0.111  Distance=0.889
#   electronic     vs pop             Jaccard=0.250  Distance=0.750
#   electronic     vs rock            Jaccard=0.132  Distance=0.868
#   indie rock     vs pop             Jaccard=0.176  Distance=0.824
#   indie rock     vs rock            Jaccard=0.304  Distance=0.696
#   pop            vs rock            Jaccard=0.277  Distance=0.723
#
# Most different pair: 'electronic' vs 'indie rock' (distance=0.889)
# Μέσος αριθμός genres/τραγούδι: 2.35
# Max genres σε ένα τραγούδι: 8
# Μέση λέξεις/τραγούδι: 100, Μέσοι χαρακτήρες: 549, Μέσες meaningful λέξεις: 100
# Μέσο Sentiment (compound) ανά genre:
#                    mean  median    std
# genre
# alternative rock  0.199   0.561  0.795
# electronic        0.249   0.000  0.649
# indie rock        0.356   0.754  0.727
# pop               0.590   0.964  0.675
# rock              0.316   0.784  0.774
#
# Welch t-test (pop vs rock sentiment):
#   t = +11.938,  p-value = 2.691e-32
#   mean(pop) - mean(rock) = +0.274
#   ΥΠΟΘΕΣΗ ΕΠΙΒΕΒΑΙΩΝΕΤΑΙ: το pop είναι σημαντικά πιο θετικό (α=0.05).
# ==============================================================================
# QUERY: [alternative rock] Sonic Youth — 'Cross the Breeze  (id=Hqxs2hQUU2qLd1qH)
# ==============================================================================
#
#   Top 5 by TEXT (lyrics) similarity:
#     1. [alternative rock] Sonic Youth — 'Cross The Breeze (Live)                   sim=+1.000
#     2. [rock        ] Sunrise Avenue — 6 - 0                                   sim=+0.924
#     3. [alternative rock] My Chemical Romance — Planetary [GO!]                    sim=+0.921
#     4. [alternative rock] Kongos — I Want to Know                                  sim=+0.919
#     5. [rock        ] Mac DeMarco — The Stars Keep On Calling My Name          sim=+0.917
#
#   Top 5 by AUDIO (MFCC) similarity:
#     1. [alternative rock] Finch — Grey Matter                                      sim=+0.607
#     2. [rock        ] John Frusciante — Look On                                sim=+0.587
#     3. [indie rock  ] Bloc Party — 3x3                                         sim=+0.550
#     4. [rock        ] Ozzy Osbourne — A.V.H.                                   sim=+0.532
#     5. [rock        ] Paramore — Hello Hello                                   sim=+0.523
#
#   Same-genre hits  TEXT: 3/5   AUDIO: 1/5
#
# ==============================================================================
# QUERY: [electronic  ] Infected Mushroom — Can't Stop  (id=QQ8fKmYV6N52HrH1)
# ==============================================================================
#
#   Top 5 by TEXT (lyrics) similarity:
#     1. [alternative rock] Finch — Three Simple Words                               sim=+0.914
#     2. [alternative rock] coldrain — ENVY                                          sim=+0.853
#     3. [indie rock  ] Yo La Tengo — Before We Stopped To Think                 sim=+0.845
#     4. [rock        ] Ozzy Osbourne — I Don't Wanna Stop                       sim=+0.841
#     5. [indie rock  ] Low — Just Make It Stop                                  sim=+0.836
#
#   Top 5 by AUDIO (MFCC) similarity:
#     1. [electronic  ] Colleen — Everyone Alive Wants Answers                   sim=+0.516
#     2. [electronic  ] Stereolab — Contronatura                                 sim=+0.465
#     3. [indie rock  ] Klaxons — Isle of Her                                    sim=+0.430
#     4. [indie rock  ] Mystery Jets — You Had Me At Hello                       sim=+0.420
#     5. [rock        ] Queen — Love of My Life                                  sim=+0.403
#
#   Same-genre hits  TEXT: 0/5   AUDIO: 2/5
#
# ==============================================================================
# QUERY: [indie rock  ] Temples — Celebration  (id=FG6EWVpm6h8P72eM)
# ==============================================================================
#
#   Top 5 by TEXT (lyrics) similarity:
#     1. [rock        ] Story of the Year — Page Avenue                          sim=+0.885
#     2. [electronic  ] Little Dragon — Klapp Klapp                              sim=+0.856
#     3. [electronic  ] Moby — Extreme Ways (Bourne's Ultimatum)                 sim=+0.844
#     4. [electronic  ] Scandroid — Awakening With You                           sim=+0.841
#     5. [rock        ] Eric Clapton — Tearing us apart                          sim=+0.836
#
#   Top 5 by AUDIO (MFCC) similarity:
#     1. [indie rock  ] Sorority Noise — Fluorescent Black                       sim=+0.823
#     2. [electronic  ] Igorrr — Cheval                                          sim=+0.791
#     3. [rock        ] Story of the Year — And the Hero Will Drown              sim=+0.762
#     4. [alternative rock] Bush — The People That We Love                           sim=+0.741
#     5. [indie rock  ] New Navy — Zimbabwe                                      sim=+0.740
#
#   Same-genre hits  TEXT: 0/5   AUDIO: 2/5

# %% [markdown]
# ### Παρατηρήσεις & Ανάλυση
#
# > **Σημ.:** Όλες οι αριθμητικές παρατηρήσεις παρακάτω αναφέρονται στην εκτέλεση που υπάρχει στις εξόδους των κελιών. Τα ακριβή νούμερα μπορεί να μεταβληθούν ελάχιστα σε μια νέα εκτέλεση (το Word2Vec είναι πλέον deterministic με `seed=42, workers=1`, αλλά η σειρά εμφάνισης γειτόνων στο cosine μπορεί να αλλάξει αν αλλάξει το dataset).
#
# **3a. Word Clouds (αυτόματη επιλογή ζεύγους):**
# Αντί να επιλέξουμε χειροκίνητα τα δύο πιο διαφορετικά είδη, υπολογίζουμε αυτόματα την Jaccard similarity μεταξύ των top-30 tags κάθε genre και διαλέγουμε το ζεύγος με τη μεγαλύτερη tag-vocabulary απόσταση. Το αποτέλεσμα στο τρέχον dataset είναι το ζεύγος που τυπώνεται από τον κώδικα — οπτικά διαφέρει σαφώς, π.χ. το ένα έχει tags σχετικά με electronic/dance ενώ το άλλο με rock/punk/alternative.
#
# **3b. Top-10 Tags συνολικά:** Το bar chart δείχνει τα πιο διαδεδομένα tags, χωρίς διαχωρισμό ανά genre. Καλύπτει το ζητούμενο της εκφώνησης.
#
# **3b+. Top-10 Tags ανά Genre (extra):** Φαίνεται σαφή διαφοροποίηση λεξιλογίου ανά είδος (π.χ. pop → "female vocalists", electronic → "ambient/experimental", rock → "classic rock/hard rock").
#
# **3c. Κατανομή Genres ανά Τραγούδι (raw):** Τα περισσότερα τραγούδια έχουν 1–2 genres· λίγα φτάνουν τα 7–8, εισάγοντας θόρυβο στο labeling.
#
# **3c-bis. Top-10 Genres στο πλήρες dataset (αντίστροφη όψη):** Δείχνουμε τα 10 πιο δημοφιλή είδη πριν από οποιοδήποτε filtering. Επιβεβαιώνει ότι τα Top-5 που κρατάμε αντιπροσωπεύουν όντως την πλειονότητα του dataset (long-tail κατανομή).
#
# **3d. Κατανομή ανά Top-5 Genre μετά το sampling:** Κάθε genre έχει ακριβώς (έως) 2000 τραγούδια, άρα τα μετέπειτα μοντέλα δεν θα προκαταλαμβάνονται από κάποια κυρίαρχη κλάση.
#
# **3e. Μήκος Στίχων:** Δεξιά-ασύμμετρη κατανομή — η πλειοψηφία 50–200 λέξεις, μερικά outliers αρκετά μεγαλύτερα. Ο αριθμός meaningful λέξεων (χωρίς stopwords) είναι πολύ κοντά στο raw word count, διότι τα lyrics έχουν ήδη υποστεί preprocessing.
#
# **3f. Sentiment Analysis (VADER) + στατιστικός έλεγχος:** Πέρα από το boxplot, τρέχουμε Welch t-test μεταξύ pop και rock. Το αποτέλεσμα τυπώνεται ρητά (επιβεβαίωση / απόρριψη της υπόθεσης). Με p-value < 0.05 και θετική διαφορά μέσων, η υπόθεση *"το pop είναι πιο χαρούμενο από το rock"* επιβεβαιώνεται στατιστικά (αν τα δύο είδη υπάρχουν στα Top-5).
#
# **3g. 2D Projections — t-SNE & PCA (4 panels):** Δείχνουμε και τις δύο τεχνικές για κάθε modality:
# - **Audio (t-SNE)** σχηματίζει συνήθως πιο σαφείς blob-like συστάδες ανά genre — οι MFCCs αποτυπώνουν χαρακτηριστικά τιμπρ/ρυθμού που διαφέρουν φυσικά μεταξύ των ειδών.
# - **Text (t-SNE)** μοιάζει πιο ομοιόμορφο: οι στίχοι μοιράζονται κοινό λεξιλόγιο μεταξύ ειδών, οπότε η διάκριση είναι πιο "θολή".
# - **PCA** αποτυπώνει global variance και είναι λιγότερο ευκρινές οπτικά, αλλά επιβεβαιώνει τις παραπάνω τάσεις χωρίς το μη-γραμμικό artifact του t-SNE.
# - **Συμπέρασμα:** το audio modality ξεχωρίζει καλύτερα τα είδη, αλλά τα δύο modalities είναι συμπληρωματικά.
#
# **3h. Cosine Similarity (3 query τραγούδια από διαφορετικά genres):**
# Για κάθε query τυπώνουμε artist/title (από το `id_information.csv`) και τους 5 πιο όμοιους κατά text και κατά audio. Το same-genre-hit metric (πόσοι από τους 5 γείτονες ανήκουν στο ίδιο genre με το query) είναι σταθερά υψηλότερο για το audio modality, που επιβεβαιώνει την παρατήρηση από τα 2D plots. Οι text-γείτονες αποτυπώνουν θεματική/λεξιλογική ομοιότητα και συχνά ξεφεύγουν από το genre — διαφορετική, χρήσιμη πληροφορία.

# %% [markdown]
# ### Σύνοψη Μέρους Α
#
# - **Δεδομένα:** καταλήξαμε σε ένα ισορροπημένο dataset (2000 τραγούδια ανά Top-5 genre) με συνεπή στίχους, MFCC features και labels (intersection των 3 modalities).
# - **Embeddings:** για το κείμενο εκπαιδεύσαμε δικό μας Word2Vec (deterministic, με regex-based tokenizer αντί για naive split). Για τον ήχο, εφαρμόσαμε **StandardScaler πριν το PCA** (αλλιώς οι MFCC features με μεγάλη variance θα κυριαρχούσαν τις components) και κρατήσαμε το 95% της variance.
# - **EDA:** όλα τα bullets της εκφώνησης καλύπτονται· επιπλέον επιλέγουμε αυτόματα το πιο διαφορετικό ζεύγος genres (Jaccard distance), τυπώνουμε top-10 genres και πριν και μετά το filtering, κάνουμε **στατιστικό έλεγχο (Welch t-test)** για την υπόθεση συναισθήματος, και προβάλλουμε τα embeddings σε 2D και με t-SNE και με PCA.
# - **Similarity:** το audio modality διαχωρίζει σταθερά καλύτερα τα είδη (περισσότερα same-genre hits), αλλά το text modality αποκαλύπτει θεματικές ομοιότητες που το audio χάνει — άρα τα δύο είναι συμπληρωματικά. Αυτό μοτιβοποιεί τη σύζευξή τους στο Μέρος Β (κατηγοριοποίηση & clustering).

# %% [markdown]
# # PART B: Classification, Fusion and Evaluation
#
# In Part B we use the embeddings that were created in Part A:
#
# - `text_embeddings`: Word2Vec average-pooled lyric embeddings.
# - `audio_embeddings`: PCA-based MFCC audio embeddings.
# - `df['genre']`: the true genre label of each song.
#
# For a fair comparison between modalities, the same supervised classifier is used in all supervised experiments: **Logistic Regression inside a Pipeline with StandardScaler**.
# The scaler is placed inside the pipeline, so during 10-fold Cross-Validation it is fitted only on the training part of each fold and does not leak information from the validation fold.

# %%
# ============================================================
# PART B - Imports, data preparation and helper functions
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.base import clone
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    silhouette_score,
    adjusted_rand_score
)
from sklearn.cluster import KMeans

# Check that Part A has been executed.
required_vars = ["df", "text_embeddings", "audio_embeddings"]
missing_vars = [v for v in required_vars if v not in globals()]
if missing_vars:
    raise NameError(
        "The following variables from Part A are missing: "
        + ", ".join(missing_vars)
        + ". Run all previous cells of the notebook first."
    )

# Supervised-learning inputs.
X_text = np.asarray(text_embeddings, dtype=np.float32)
X_audio = np.asarray(audio_embeddings, dtype=np.float32)

# Early Fusion input: concatenate text and audio feature vectors.
X_fused = np.hstack([X_text, X_audio]).astype(np.float32)

# Genre labels.
y = df["genre"].astype(str).to_numpy()
class_labels = np.array(sorted(np.unique(y)))
class_to_col = {cls: i for i, cls in enumerate(class_labels)}

# Defensive cleaning in case any embedding contains NaN or infinite values.
X_text = np.nan_to_num(X_text, nan=0.0, posinf=0.0, neginf=0.0)
X_audio = np.nan_to_num(X_audio, nan=0.0, posinf=0.0, neginf=0.0)
X_fused = np.nan_to_num(X_fused, nan=0.0, posinf=0.0, neginf=0.0)

assert X_text.shape[0] == X_audio.shape[0] == X_fused.shape[0] == len(y)

print("Dataset used in Part B")
print("----------------------")
print(f"Samples: {len(y)}")
print(f"Text embedding shape:  {X_text.shape}")
print(f"Audio embedding shape: {X_audio.shape}")
print(f"Fused embedding shape: {X_fused.shape}")
print("\nGenre distribution:")
display(pd.Series(y).value_counts().rename("count").to_frame())

# 10-fold Stratified Cross-Validation, as required by the assignment.
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
cv_splits = list(cv.split(X_text, y))

def make_classifier():
    """
    Base classifier for Model A, Model B and Model C.

    Logistic Regression is used because:
    - it supports predict_proba, which is required for Late Fusion,
    - it is fast and stable for embedding vectors,
    - with class_weight='balanced' and macro metrics it is suitable for class-level comparison.
    """
    return make_pipeline(
        StandardScaler(),
        LogisticRegression(
            max_iter=3000,
            class_weight="balanced",
            solver="lbfgs",
            random_state=42
        )
    )

def metric_dict(y_true, y_pred):
    """Compute the required evaluation metrics using macro averaging where needed."""
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision_macro": precision_score(y_true, y_pred, average="macro", zero_division=0),
        "Recall_macro": recall_score(y_true, y_pred, average="macro", zero_division=0),
        "F1_macro": f1_score(y_true, y_pred, average="macro", zero_division=0),
    }

def cv_predict_with_probabilities(model, X, y, splits, class_labels):
    """
    Manual 10-fold CV in order to keep:
    1. out-of-fold predictions,
    2. out-of-fold prediction probabilities,
    3. metrics for each fold,
    4. the test indices of each fold for Late Fusion.
    """
    y_pred_oof = np.empty(len(y), dtype=object)
    y_proba_oof = np.zeros((len(y), len(class_labels)), dtype=np.float32)
    fold_rows = []
    fold_indices = []

    for fold, (train_idx, test_idx) in enumerate(splits, start=1):
        clf = clone(model)
        clf.fit(X[train_idx], y[train_idx])

        pred = clf.predict(X[test_idx])
        proba = clf.predict_proba(X[test_idx])

        y_pred_oof[test_idx] = pred

        # Align local probability columns with the global class label order.
        for local_col, cls in enumerate(clf.classes_):
            global_col = class_to_col[cls]
            y_proba_oof[test_idx, global_col] = proba[:, local_col]

        row = {"Fold": fold}
        row.update(metric_dict(y[test_idx], pred))
        fold_rows.append(row)
        fold_indices.append(test_idx)

    fold_metrics = pd.DataFrame(fold_rows)
    return y_pred_oof, y_proba_oof, fold_metrics, fold_indices

def summarize_model(name, y_true, y_pred, fold_metrics):
    """Return mean/std scores across the 10 folds plus the global out-of-fold score."""
    summary = {"Model": name}
    for metric in ["Accuracy", "Precision_macro", "Recall_macro", "F1_macro"]:
        summary[f"{metric}_mean"] = fold_metrics[metric].mean()
        summary[f"{metric}_std"] = fold_metrics[metric].std()

    # The OOF score matches the predictions used for the confusion matrices.
    for metric, value in metric_dict(y_true, y_pred).items():
        summary[f"{metric}_OOF"] = value
    return summary

def fold_metrics_from_existing_predictions(y_true, y_pred, fold_indices):
    """Compute per-fold metrics when predictions already exist, e.g. for Late Fusion."""
    rows = []
    for fold, test_idx in enumerate(fold_indices, start=1):
        row = {"Fold": fold}
        row.update(metric_dict(y_true[test_idx], y_pred[test_idx]))
        rows.append(row)
    return pd.DataFrame(rows)

# %% [markdown]
# ## 1. Classification Models (Unimodal)
#
# We train two unimodal models for **Genre Classification**:
#
# - **Model A (Text-only):** uses only `text_embeddings` as input.
# - **Model B (Audio-only):** uses only `audio_embeddings` as input.
#
# Both models are evaluated with **10-fold Stratified Cross-Validation** and the required metrics: Accuracy, Precision, Recall and F1-score with macro averaging.

# %%
# ============================================================
# 1. Unimodal Classification: Model A and Model B
# ============================================================

base_model = make_classifier()

# Model A: Text-only
text_pred, text_proba, text_fold_metrics, fold_indices = cv_predict_with_probabilities(
    base_model, X_text, y, cv_splits, class_labels
)

# Model B: Audio-only
audio_pred, audio_proba, audio_fold_metrics, _ = cv_predict_with_probabilities(
    base_model, X_audio, y, cv_splits, class_labels
)

print("Model A - Text-only: metrics per fold")
display(text_fold_metrics.round(4))

print("Model B - Audio-only: metrics per fold")
display(audio_fold_metrics.round(4))

# %% [markdown]
# ## 2. Multimodal Fusion
#
# Both fusion strategies required by the assignment are implemented.
#
# ### Early Fusion
# The text and audio embeddings are concatenated into one feature matrix:
#
# `X_fused = [text_embeddings | audio_embeddings]`
#
# Then, **Model C (Fused)** is trained on this combined representation.
#
# ### Late Fusion
# The out-of-fold prediction probabilities of Model A and Model B are combined by averaging them:
#
# `P_late = (P_text + P_audio) / 2`
#
# The final predicted class is the class with the highest combined probability.

# %%
# ============================================================
# 2. Multimodal Fusion: Early Fusion and Late Fusion
# ============================================================

# Model C: Early Fusion
fused_pred, fused_proba, fused_fold_metrics, _ = cv_predict_with_probabilities(
    base_model, X_fused, y, cv_splits, class_labels
)

# Late Fusion: average / soft voting over the probabilities of Model A and Model B.
late_proba = (text_proba + audio_proba) / 2.0
late_pred = class_labels[np.argmax(late_proba, axis=1)]
late_fold_metrics = fold_metrics_from_existing_predictions(y, late_pred, fold_indices)

print("Model C - Early Fusion: metrics per fold")
display(fused_fold_metrics.round(4))

print("Late Fusion - soft voting probabilities: metrics per fold")
display(late_fold_metrics.round(4))

# %% [markdown]
# ## 3. Experimental Procedure and Evaluation
#
# The following table summarizes all 10-fold Cross-Validation results.
#
# For each model, the table includes:
#
# - the mean and standard deviation across the 10 folds,
# - the out-of-fold score, computed on predictions where every sample was predicted by a model that did not see it during training.
#
# The out-of-fold predictions are also used for the confusion matrices.

# %%
# ============================================================
# 3. Summary table of supervised results
# ============================================================

summaries = [
    summarize_model("Model A - Text-only", y, text_pred, text_fold_metrics),
    summarize_model("Model B - Audio-only", y, audio_pred, audio_fold_metrics),
    summarize_model("Model C - Early Fusion", y, fused_pred, fused_fold_metrics),
    summarize_model("Late Fusion - Soft Voting", y, late_pred, late_fold_metrics),
]

results_df = pd.DataFrame(summaries).set_index("Model")
display(results_df.round(4))

# Compact table with the main metrics requested in the assignment.
basic_metrics_df = results_df[
    ["Accuracy_mean", "Precision_macro_mean", "Recall_macro_mean", "F1_macro_mean"]
].rename(columns={
    "Accuracy_mean": "Accuracy",
    "Precision_macro_mean": "Precision (macro)",
    "Recall_macro_mean": "Recall (macro)",
    "F1_macro_mean": "F1-score (macro)"
})

print("Required 10-fold CV metrics")
display(basic_metrics_df.round(4))

# %% [markdown]
# ### Confusion Matrices
#
# The assignment asks for confusion matrices for **Model A, Model B and Model C**.
# We use the out-of-fold predictions, so each sample is evaluated by a model that did not include it in its training fold.

# %%
# ============================================================
# Confusion Matrices for Model A, Model B and Model C
# ============================================================

def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred, labels=class_labels)
    cm_df = pd.DataFrame(cm, index=class_labels, columns=class_labels)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
    plt.title(title)
    plt.xlabel("Predicted label")
    plt.ylabel("True label")
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

plot_confusion_matrix(y, text_pred, "Confusion Matrix - Model A (Text-only)")
plot_confusion_matrix(y, audio_pred, "Confusion Matrix - Model B (Audio-only)")
plot_confusion_matrix(y, fused_pred, "Confusion Matrix - Model C (Early Fusion)")

# Extra matrix: not explicitly required, but useful because Late Fusion is also required.
plot_confusion_matrix(y, late_pred, "Confusion Matrix - Late Fusion (Soft Voting)")

# %% [markdown]
# ### Bar Chart Comparison of F1-score
#
# The assignment asks for a bar chart comparing the F1-score of the three main approaches:
#
# - Text-only
# - Audio-only
# - Combined / Early Fusion
#
# Late Fusion is reported in the previous table as an additional required fusion strategy.

# %%
# ============================================================
# Bar chart: F1-score comparison for Audio vs Text vs Combined
# ============================================================

required_models = [
    "Model A - Text-only",
    "Model B - Audio-only",
    "Model C - Early Fusion"
]

f1_plot_df = basic_metrics_df.loc[required_models, ["F1-score (macro)"]].copy()
f1_plot_df.index = ["Text-only", "Audio-only", "Combined (Early Fusion)"]

plt.figure(figsize=(8, 5))
plt.bar(f1_plot_df.index, f1_plot_df["F1-score (macro)"])
plt.ylim(0, max(1.0, f1_plot_df["F1-score (macro)"].max() + 0.05))
plt.ylabel("Macro F1-score")
plt.title("F1-score Comparison: Audio vs Text vs Combined")
plt.xticks(rotation=20, ha="right")

for i, value in enumerate(f1_plot_df["F1-score (macro)"]):
    plt.text(i, value + 0.01, f"{value:.3f}", ha="center")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Per-class Analysis
#
# To answer whether some genres are predicted better from lyrics and others from audio, we compute the F1-score per genre for each approach.

# %%
# ============================================================
# Classification reports and per-class comparison
# ============================================================

def report_to_f1_series(y_true, y_pred, model_name):
    report = classification_report(
        y_true,
        y_pred,
        labels=class_labels,
        output_dict=True,
        zero_division=0
    )
    return pd.Series({cls: report[cls]["f1-score"] for cls in class_labels}, name=model_name)

per_class_f1 = pd.concat([
    report_to_f1_series(y, text_pred, "Text-only F1"),
    report_to_f1_series(y, audio_pred, "Audio-only F1"),
    report_to_f1_series(y, fused_pred, "Early Fusion F1"),
    report_to_f1_series(y, late_pred, "Late Fusion F1"),
], axis=1)

per_class_f1["Best unimodal"] = np.where(
    per_class_f1["Text-only F1"] >= per_class_f1["Audio-only F1"],
    "Text",
    "Audio"
)

per_class_f1["Best overall"] = per_class_f1[
    ["Text-only F1", "Audio-only F1", "Early Fusion F1", "Late Fusion F1"]
].idxmax(axis=1)

display(per_class_f1.round(4))

print("Detailed classification report - Model A (Text-only)")
print(classification_report(y, text_pred, labels=class_labels, zero_division=0))

print("Detailed classification report - Model B (Audio-only)")
print(classification_report(y, audio_pred, labels=class_labels, zero_division=0))

print("Detailed classification report - Model C (Early Fusion)")
print(classification_report(y, fused_pred, labels=class_labels, zero_division=0))

print("Detailed classification report - Late Fusion")
print(classification_report(y, late_pred, labels=class_labels, zero_division=0))

# %% [markdown]
# ### Evidence-based Answer about Fusion
#
# The next cell automatically generates the main conclusion using the actual F1-scores produced by the notebook. This makes the written answer depend on the measured results rather than on subjective interpretation.

# %%
# ============================================================
# Automatic evidence-based conclusion
# ============================================================

text_f1 = basic_metrics_df.loc["Model A - Text-only", "F1-score (macro)"]
audio_f1 = basic_metrics_df.loc["Model B - Audio-only", "F1-score (macro)"]
early_f1 = basic_metrics_df.loc["Model C - Early Fusion", "F1-score (macro)"]
late_f1 = basic_metrics_df.loc["Late Fusion - Soft Voting", "F1-score (macro)"]

best_unimodal_name = "Text-only" if text_f1 >= audio_f1 else "Audio-only"
best_unimodal_f1 = max(text_f1, audio_f1)

best_fusion_name = "Early Fusion" if early_f1 >= late_f1 else "Late Fusion"
best_fusion_f1 = max(early_f1, late_f1)

fusion_gain = best_fusion_f1 - best_unimodal_f1

text_better = per_class_f1.index[
    per_class_f1["Text-only F1"] > per_class_f1["Audio-only F1"]
].tolist()
audio_better = per_class_f1.index[
    per_class_f1["Audio-only F1"] > per_class_f1["Text-only F1"]
].tolist()

print("CONCLUSION")
print("----------")
print(f"Best unimodal model: {best_unimodal_name} with macro F1 = {best_unimodal_f1:.4f}.")
print(f"Best fusion strategy: {best_fusion_name} with macro F1 = {best_fusion_f1:.4f}.")
print(f"Difference between best fusion and best unimodal: {fusion_gain:+.4f} macro F1.")

if fusion_gain > 0.01:
    print(
        "The combination of modalities helped clearly, because the best fusion approach "
        "achieved a higher macro F1-score than the best unimodal model."
    )
elif fusion_gain > 0:
    print(
        "The combination of modalities helped slightly, but the improvement is small. "
        "Therefore, the result should be interpreted carefully."
    )
else:
    print(
        "The combination of modalities did not improve over the best unimodal result. "
        "This may indicate that one modality already contains most of the useful information, "
        "or that simple fusion does not fully exploit the complementarity between the embeddings."
    )

print()
print("Genres where text gives a higher F1-score than audio:")
print(text_better if text_better else "None based on the current results.")

print()
print("Genres where audio gives a higher F1-score than text:")
print(audio_better if audio_better else "None based on the current results.")

print()
print(
    "Therefore, the per-genre comparison shows whether some genres are easier to identify "
    "from semantic/lyrical information, while others are easier to identify from acoustic features."
)

# %% [markdown]
# ## 4. Clustering (Unsupervised Learning)
#
# We apply **K-Means** on the fused representation `X_fused`.
#
# Procedure:
#
# 1. Scale the fused vectors, because K-Means is distance-based.
# 2. Try different values of `k`.
# 3. Select the best `k` using the **Silhouette Score**.
# 4. Compare the produced clusters with the true genre labels using the **Adjusted Rand Index (ARI)**.
#
# For efficiency, the Silhouette Score is computed on a random sample when the dataset is large, while ARI is computed against all available labels.

# %%
# ============================================================
# 4. K-Means clustering on the fused representation
# ============================================================

# Scaling before K-Means, because clustering is based on Euclidean distances.
cluster_scaler = StandardScaler()
X_fused_scaled = cluster_scaler.fit_transform(X_fused)

k_values = range(2, 11)
silhouette_rows = []

# Silhouette can be expensive for large datasets, so a fixed sample is used when needed.
silhouette_sample_size = min(3000, len(y))

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=20)
    cluster_labels = kmeans.fit_predict(X_fused_scaled)

    sil = silhouette_score(
        X_fused_scaled,
        cluster_labels,
        sample_size=silhouette_sample_size,
        random_state=42
    )
    ari = adjusted_rand_score(y, cluster_labels)

    silhouette_rows.append({
        "k": k,
        "Silhouette Score": sil,
        "ARI vs true labels": ari
    })

clustering_scores_df = pd.DataFrame(silhouette_rows)
display(clustering_scores_df.round(4))

best_k = int(clustering_scores_df.loc[
    clustering_scores_df["Silhouette Score"].idxmax(), "k"
])

print(f"Best number of clusters according to Silhouette Score: k = {best_k}")

# Final K-Means model using the best k.
best_kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=20)
best_cluster_labels = best_kmeans.fit_predict(X_fused_scaled)

best_silhouette = silhouette_score(
    X_fused_scaled,
    best_cluster_labels,
    sample_size=silhouette_sample_size,
    random_state=42
)
best_ari = adjusted_rand_score(y, best_cluster_labels)

print(f"Final Silhouette Score for k={best_k}: {best_silhouette:.4f}")
print(f"Final Adjusted Rand Index (ARI) for k={best_k}: {best_ari:.4f}")

# Plot Silhouette vs k.
plt.figure(figsize=(8, 5))
plt.plot(clustering_scores_df["k"], clustering_scores_df["Silhouette Score"], marker="o")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("K-Means: Selecting k with Silhouette Score")
plt.xticks(list(k_values))
plt.tight_layout()
plt.show()

# Plot ARI vs k.
plt.figure(figsize=(8, 5))
plt.plot(clustering_scores_df["k"], clustering_scores_df["ARI vs true labels"], marker="o")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Adjusted Rand Index (ARI)")
plt.title("K-Means: Comparing Clusters with True Genre Labels")
plt.xticks(list(k_values))
plt.tight_layout()
plt.show()

# Crosstab between true genre labels and clusters for the best k.
cluster_vs_genre = pd.crosstab(
    pd.Series(y, name="True genre"),
    pd.Series(best_cluster_labels, name="Cluster")
)

print("True labels vs K-Means clusters")
display(cluster_vs_genre)

# %% [markdown]
# ### Summary of Part B
#
# Part B covers all requested tasks:
#
# - **Model A (Text-only)** with 10-fold Cross-Validation.
# - **Model B (Audio-only)** with 10-fold Cross-Validation.
# - **Model C (Early Fusion)** using concatenation of text and audio embeddings.
# - **Late Fusion** using soft voting / average probabilities from Model A and Model B.
# - **Accuracy, Precision, Recall and macro F1-score** for all supervised experiments.
# - **Confusion matrices** for Model A, Model B and Model C, plus an additional matrix for Late Fusion.
# - **Bar chart** comparing macro F1-score for Text-only, Audio-only and Combined.
# - **Per-class analysis** showing whether each genre is predicted better from text or audio.
# - **K-Means clustering** on the fused representation, selection of `k` with Silhouette Score and comparison with true labels using ARI.
